# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import log_parser

# %%
log_parser.analyse_logs("/media/hdd1/neuro_logs/",show_instance_html=True)
# Out:
# Removed long (114432) line.
# Removed long (38181) line.
# Found an error in /media/hdd1/neuro_logs/11-06-2017_18-53-06.log, skipping it.
# Found an error in /media/hdd1/neuro_logs/11-06-2017_17-33-57.log, skipping it.
# Found an error in /media/hdd1/neuro_logs/11-06-2017_17-33-51.log, skipping it.
# Found an error in /media/hdd1/neuro_logs/11-06-2017_17-32-33.log, skipping it.
# Removed long (114432) line.
# Removed long (38273) line.
#     <style type='text/css'>
#     div.root {
#         text-align: left;
#     }
#
#     div.file_title {
#         font-size: 2em;
#         margin-top: 1em;
#         margin-bottom: 1em;
#     }
#
#     .smaller {
#         font-size: 0.9em;
#     }
#     .parsed {
#         margin-bottom: 15px;
#     }
#
#     hr {
#         border: 0;
#         border-top: 1px solid;
#         display: block;
#         margin-left: 0;
#         margin-top: 60 px;
#         margin-bottom: 60 px;
#     }
#
#     hr.file_seperator {
#         width: 80%;
# ...

# %% [markdown]
# gamma has litterally no effect
